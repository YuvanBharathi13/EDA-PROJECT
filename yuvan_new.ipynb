# %% [markdown]
# <a href="https://colab.research.google.com/github/YuvanBharathi13/EDA-PROJECT/blob/main/yuvan_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# git hub link - https://github.com/YuvanBharathi13/EDA-PROJECT/blob/main/yuvan_new.ipynb

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Liver%20Data.csv")
df.head()
# Out:
#    Age of the patient Gender of the patient  Total Bilirubin  \
# 0                65.0                Female              0.7
# 1                62.0                  Male             10.9
# 2                62.0                  Male              7.3
# 3                58.0                  Male              1.0
# 4                72.0                  Male              3.9
#
#    Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0               0.1                          187.0
# 1               5.5                          699.0
# 2               4.1                          490.0
# 3               0.4                          182.0
# 4               2.0                          195.0
#
#     Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                            16.0                             18.0
# 1                            64.0                            100.0
# 2                            60.0                             68.0
# 3                            14.0                             20.0
# 4                            27.0                             59.0
#
#    Total Protiens   ALB Albumin  A/G Ratio Albumin and Globulin Ratio  Result
# 0             6.8           3.3                                  0.90       1
# 1             7.5           3.2                                  0.74       1
# 2             7.0           3.3                                  0.89       1
# 3             6.8           3.4                                  1.00       1
# 4             7.3           2.4                                  0.40       1

# %%
df.describe()
# Out:
#        Age of the patient  Total Bilirubin  Direct Bilirubin  \
# count        30689.000000     30043.000000      30130.000000
# mean            44.107205         3.370319          1.528042
# std             15.981043         6.255522          2.869592
# min              4.000000         0.400000          0.100000
# 25%             32.000000         0.800000          0.200000
# 50%             45.000000         1.000000          0.300000
# 75%             55.000000         2.700000          1.300000
# max             90.000000        75.000000         19.700000
#
#         Alkphos Alkaline Phosphotase   Sgpt Alamine Aminotransferase  \
# count                   29895.000000                    30153.000000
# mean                      289.075364                       81.488641
# std                       238.537589                      182.158850
# min                        63.000000                       10.000000
# 25%                       175.000000                       23.000000
# 50%                       209.000000                       35.000000
# 75%                       298.000000                       62.000000
# max                      2110.000000                     2000.000000
#
#        Sgot Aspartate Aminotransferase  Total Protiens   ALB Albumin  \
# count                     30229.000000    30228.000000  30197.000000
# mean                        111.469979        6.480237      3.130142
# std                         280.851078        1.081980      0.792281
# min                          10.000000        2.700000      0.900000
# 25%                          26.000000        5.800000      2.600000
# 50%                          42.000000        6.600000      3.100000
# 75%                          88.000000        7.200000      3.800000
# max                        4929.000000        9.600000      5.500000
#
#        A/G Ratio Albumin and Globulin Ratio        Result
# count                          30132.000000  30691.000000
# mean                               0.943467      1.285882
# std                                0.323164      0.451841
# min                                0.300000      1.000000
# 25%                                0.700000      1.000000
# 50%                                0.900000      1.000000
# 75%                                1.100000      2.000000
# max                                2.800000      2.000000

# %% [markdown]
# Even though there are multiple rows with the same value there is no need to drop all duplicate rows because when it comes to medical data it is common for patients with the same condition to exhibit similar biochemical values.

# %%
pd.value_counts(df.duplicated())
# Out:
# <ipython-input-167-e6b28e2d5271>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df.duplicated())
# False    19368
# True     11323
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age of the patient                        2
# Gender of the patient                   902
# Total Bilirubin                         648
# Direct Bilirubin                        561
#  Alkphos Alkaline Phosphotase           796
#  Sgpt Alamine Aminotransferase          538
# Sgot Aspartate Aminotransferase         462
# Total Protiens                          463
#  ALB Albumin                            494
# A/G Ratio Albumin and Globulin Ratio    559
# Result                                    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5425

# %%
df.isna()
# Out:
#        Age of the patient  Gender of the patient  Total Bilirubin  \
# 0                   False                  False            False
# 1                   False                  False            False
# 2                   False                  False            False
# 3                   False                  False            False
# 4                   False                  False            False
# ...                   ...                    ...              ...
# 30686               False                  False            False
# 30687               False                  False            False
# 30688               False                  False            False
# 30689               False                  False            False
# 30690               False                  False            False
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                 False                          False
# 1                 False                          False
# 2                 False                          False
# 3                 False                          False
# 4                 False                          False
# ...                 ...                            ...
# 30686             False                          False
# 30687             False                          False
# 30688             False                          False
# 30689             False                          False
# 30690             False                          False
#
#         Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                               False                            False
# 1                               False                            False
# 2                               False                            False
# 3                               False                            False
# 4                               False                            False
# ...                               ...                              ...
# 30686                           False                            False
# 30687                           False                            False
# 30688                           False                            False
# 30689                           False                            False
# 30690                           False                            False
#
#        Total Protiens   ALB Albumin  A/G Ratio Albumin and Globulin Ratio  \
# 0               False         False                                 False
# 1               False         False                                 False
# 2               False         False                                 False
# 3               False         False                                 False
# 4               False         False                                 False
# ...               ...           ...                                   ...
# 30686           False         False                                 False
# 30687           False         False                                 False
# 30688           False         False                                 False
# 30689           False         False                                 False
# 30690           False         False                                 False
#
#        Result
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 30686   False
# 30687   False
# 30688   False
# 30689   False
# 30690   False
#
# [30691 rows x 11 columns]

# %% [markdown]
# Since Gender plays an important role in the analysis rows without a gender should be removed becuase the human anotamy of the male and the female are completely different.

# %%
pd.value_counts(df["Gender of the patient"].isna())
# Out:
# <ipython-input-171-04003d2cde1d>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df["Gender of the patient"].isna())
# Gender of the patient
# False    29789
# True       902
# Name: count, dtype: int64

# %%
df1 = df.dropna(subset=["Gender of the patient"])
pd.value_counts(df1["Gender of the patient"].isna())
# Out:
# <ipython-input-172-e0b3cadcd415>:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df1["Gender of the patient"].isna())
# Gender of the patient
# False    29789
# Name: count, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Age of the patient                        2
# Gender of the patient                     0
# Total Bilirubin                         419
# Direct Bilirubin                        459
#  Alkphos Alkaline Phosphotase           726
#  Sgpt Alamine Aminotransferase          481
# Sgot Aspartate Aminotransferase         409
# Total Protiens                          422
#  ALB Albumin                            455
# A/G Ratio Albumin and Globulin Ratio    517
# Result                                    0
# dtype: int64

# %%
df1.columns = [col.strip() for col in df1.columns] # cleaning the names of the columns by using strip() function

# %%
for i in df1.columns:
  print(i)
# Out:
# Age of the patient
# Gender of the patient
# Total Bilirubin
# Direct Bilirubin
# Alkphos Alkaline Phosphotase
# Sgpt Alamine Aminotransferase
# Sgot Aspartate Aminotransferase
# Total Protiens
# ALB Albumin
# A/G Ratio Albumin and Globulin Ratio
# Result

# %%
for col in df1.columns:
  x = df1[col] == "?"
  print(x.value_counts()) # checking if each column has any "?" in them
# Out:
# Age of the patient
# False    29789
# Name: count, dtype: int64
# Gender of the patient
# False    29789
# Name: count, dtype: int64
# Total Bilirubin
# False    29789
# Name: count, dtype: int64
# Direct Bilirubin
# False    29789
# Name: count, dtype: int64
# Alkphos Alkaline Phosphotase
# False    29789
# Name: count, dtype: int64
# Sgpt Alamine Aminotransferase
# False    29789
# Name: count, dtype: int64
# Sgot Aspartate Aminotransferase
# False    29789
# Name: count, dtype: int64
# Total Protiens
# False    29789
# Name: count, dtype: int64
# ALB Albumin
# False    29789
# Name: count, dtype: int64
# A/G Ratio Albumin and Globulin Ratio
# False    29789
# Name: count, dtype: int64
# Result
# False    29789
# Name: count, dtype: int64

# %%
# cleaning Age of the patient column

# %%
df1.loc[:,"Age of the patient"] = df["Age of the patient"].replace(to_replace=np.nan,value=df["Age of the patient"].mean())

# %%
df1.isnull().sum()
# Out:
# Age of the patient                        0
# Gender of the patient                     0
# Total Bilirubin                         419
# Direct Bilirubin                        459
# Alkphos Alkaline Phosphotase            726
# Sgpt Alamine Aminotransferase           481
# Sgot Aspartate Aminotransferase         409
# Total Protiens                          422
# ALB Albumin                             455
# A/G Ratio Albumin and Globulin Ratio    517
# Result                                    0
# dtype: int64

# %%
# cleaning Total Bilirubin column

# %%
df1.loc[:,"Total Bilirubin"] = df["Total Bilirubin"].replace(to_replace=np.nan,value=df["Total Bilirubin"].mean())

# %%
df1.isnull().sum()
# Out:
# Age of the patient                        0
# Gender of the patient                     0
# Total Bilirubin                           0
# Direct Bilirubin                        459
# Alkphos Alkaline Phosphotase            726
# Sgpt Alamine Aminotransferase           481
# Sgot Aspartate Aminotransferase         409
# Total Protiens                          422
# ALB Albumin                             455
# A/G Ratio Albumin and Globulin Ratio    517
# Result                                    0
# dtype: int64

# %%
for column in df1.columns:
    if column == "Gender of the patient":
      continue
    else:
      df1.loc[:, column] = df1[column].replace(to_replace=np.nan, value=df1[column].mean())

# %%
df1.isnull().sum()
# Out:
# Age of the patient                      0
# Gender of the patient                   0
# Total Bilirubin                         0
# Direct Bilirubin                        0
# Alkphos Alkaline Phosphotase            0
# Sgpt Alamine Aminotransferase           0
# Sgot Aspartate Aminotransferase         0
# Total Protiens                          0
# ALB Albumin                             0
# A/G Ratio Albumin and Globulin Ratio    0
# Result                                  0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# We can see that majority of the patients were male.

# %%
df1["Gender of the patient"].value_counts().plot(kind="bar",figsize=(10,6))
# Out:
# <Axes: xlabel='Gender of the patient'>

# %%
df1["Result"].value_counts().plot(kind="pie",figsize=(10,6))
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(y="Age of the patient",data=df1)
plt.show()

# %%
sns.boxplot(x="Sgot Aspartate Aminotransferase",data=df1)
plt.show()

# %%
quarter = df1["Sgot Aspartate Aminotransferase"].quantile(0.25)
three_quarter = df1["Sgot Aspartate Aminotransferase"].quantile(0.75)
IQR = three_quarter-quarter
filt = df1["Sgot Aspartate Aminotransferase"] > (three_quarter+(1.5*IQR))
filt.value_counts()
# Out:
# Sgot Aspartate Aminotransferase
# False    26498
# True      3291
# Name: count, dtype: int64

# %% [markdown]
# All the values that come under True are all outliers

# %%
filt.value_counts().plot(kind="pie",figsize=(10,6))
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(x="Alkphos Alkaline Phosphotase",data=df1)
plt.show()

# %%
quarter = df1["Alkphos Alkaline Phosphotase"].quantile(0.25)
three_quarter = df1["Alkphos Alkaline Phosphotase"].quantile(0.75)
IQR = three_quarter-quarter
filt = df1["Alkphos Alkaline Phosphotase"] > (three_quarter+(1.5*IQR))
filt.value_counts()
# Out:
# Alkphos Alkaline Phosphotase
# False    26359
# True      3430
# Name: count, dtype: int64

# %%
sns.boxplot(x="Total Protiens",data=df1)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df1["Age of the patient"], bins=10, color='gold', edgecolor='purple')
plt.title('Age of the patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Bivariate Analaysis

# %%
plt.scatter(df1["ALB Albumin"], df1["Total Protiens"],s=10)
plt.title("Scatter Plot for Total Proteins vs ALB Albumin")
plt.ylabel("Total Proteins")
plt.xlabel("ALB Albumin")
plt.figure(figsize=(10,10))

# %%
plt.figure(figsize=(10, 10))
plt.scatter(df1["ALB Albumin"], df1["Total Protiens"], s=10)
plt.title("Scatter Plot for ALB Albumin vs Total Proteins")
plt.ylabel("Total Proteins")
plt.xlabel("ALB Albumin")

x = df1["ALB Albumin"]
y = df1["Total Protiens"]
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept
plt.plot(x, regression_line, color='red', label=f'Line: y={slope:.2f}x+{intercept:.2f}')
plt.legend()
plt.show()

# %%
sns.boxplot(x="Gender of the patient", y="Age of the patient", data=df1,color="green")
plt.title('Gender and Age')
plt.show()

# %%
sns.boxplot(x="Result", y="Age of the patient", data=df1)
plt.title('Age and Result')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df1["A/G Ratio Albumin and Globulin Ratio"], df1["ALB Albumin"],s=20)
plt.title("Scatter Plot for horsepower vs price")
plt.ylabel("ALB Albumin")
plt.xlabel("A/G Ratio Albumin and Globulin Ratio")

y = df1["ALB Albumin"]
x = df1["A/G Ratio Albumin and Globulin Ratio"]
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept
plt.plot(x, regression_line, color='red', label=f'Line: y={slope:.2f}x+{intercept:.2f}')
plt.legend()
plt.show()

# %% [markdown]
# **VIOLEN PLOT**

# %%
sns.violinplot(x='Gender of the patient', y='Result', data=df1)
plt.title('Violin Plot')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df1)
plt.title('Pair Plot')
plt.show()

# %%
df_excluded = df1.drop(columns=["Gender of the patient","Result"])
sns.heatmap(df_excluded.corr(), annot=True)
plt.title('Correlation Heatmap')
plt.figure(figsize=(100,10))
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df1["Age of the patient"], df1["Total Protiens"], df1["ALB Albumin"], c='r', marker='o',s=5)

ax.set_xlabel('Age of patienta')
ax.set_ylabel("Total Proteins")
ax.set_zlabel('ALB Albumin')

plt.title('3D Scatter Plot')
plt.show()

# %%
colors = df1["Age of the patient"]
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df1["Age of the patient"], df1["Total Protiens"], df1["ALB Albumin"], c=colors, cmap='viridis', marker='o', s=50)
ax.set_xlabel('Age of patient')
ax.set_ylabel("Total Proteins")
ax.set_zlabel('ALB Albumin')
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Age of the patient')
plt.title('3D Scatter Plot with Color Mapping')
plt.show()

# %% [markdown]
# # Part 2

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df1.columns
# Out:
# Index(['Age of the patient', 'Gender of the patient', 'Total Bilirubin',
#        'Direct Bilirubin', 'Alkphos Alkaline Phosphotase',
#        'Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        'Total Protiens', 'ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio',
#        'Result'],
#       dtype='object')

# %%
df_sampled = df1.sample(n=500, random_state=42)
X = df_sampled.loc[:,['Total Protiens']]
Y = df_sampled.loc[:,['Age of the patient']]

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(X)
Y_norm = scaler.fit_transform(Y)
new_data = np.concatenate((X_norm,Y_norm),axis=1)

# %%
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(new_data)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(new_data)

plt.figure(figsize=(10, 6))
plt.scatter(new_data[:, 0], new_data[:, 1], c=clusters, cmap='viridis', s=50)
plt.xlabel('CarsTaxis (Standardized)')
plt.ylabel('PedalCycles (Standardized)')
plt.title('Scatter Plot of Clusters')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ## hierarchical clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(X)
Y_norm = scaler.fit_transform(Y)
new_data = np.concatenate((X_norm, Y_norm), axis=1)

# %%
linked = linkage(new_data, method='ward')

# dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Dendrogram for Hierarchical Clustering')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
X = df1.loc[:, ['Total Protiens']]
Y = df1.loc[:, ['ALB Albumin']]

# %%
# Standardize the data
scaler = StandardScaler()
X_norm = scaler.fit_transform(X)
Y_norm = scaler.fit_transform(Y)
new_data = np.concatenate((X_norm, Y_norm), axis=1)

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(new_data)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], s=50,color="red")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Total Proteins and Age of the Patient')
plt.grid(True)
plt.show()

# %%
explained_variance = pca.explained_variance_ratio_
print("Explained variance by each principal component:", explained_variance)
# Out:
# Explained variance by each principal component: [0.88389005 0.11610995]

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
numeric_df = df1.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()

# heatmap plot
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
df_sampled = df1.sample(n=1000, random_state=42)
X = df_sampled.loc[:, ['ALB Albumin']].values
y = df_sampled.loc[:, ['Total Protiens']].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
model = regressor.fit(X_train,y_train)

# %%
print(f"co-efficient : {model.coef_}")
print(f"intercept : {model.intercept_}")
# Out:
# co-efficient : [[1.05426874]]
# intercept : [3.17879977]

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regressor.predict(X_train),color="red")
plt.title("Linear Regression")
plt.xlabel("Age of the patient")
plt.ylabel("Total Protiens")
plt.show()

# %%
plt.scatter(X_test,y_test)
plt.plot(X_train,regressor.predict(X_train),color="red")
plt.title("Linear Regression")
plt.xlabel("Age of the patient")
plt.ylabel("Total Protiens")
plt.show()

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
X = df1.loc[:,['Age of the patient','Total Protiens','A/G Ratio Albumin and Globulin Ratio','Total Bilirubin']].values
y = df1.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=0)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=5)
model = classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.89      0.90      0.90      7074
#            2       0.75      0.73      0.74      2856
#
#     accuracy                           0.85      9930
#    macro avg       0.82      0.82      0.82      9930
# weighted avg       0.85      0.85      0.85      9930

# %%
# sample input to see what it predicts
y_pred = classifier.predict([[60,6.9,0.66,4.3]])
print(y_pred) # the answer means it is positive.
# Out:
# [1]

# %%
from scipy.stats import kurtosis, skew

age_skewness = skew(df1['Age of the patient'])
age_kurtosis = kurtosis(df1['Age of the patient'])

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['Age of the patient'], bins=30, kde=True, color='black')
plt.title('Distribution of Age of the Patient')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.text(0.7, 0.9, f'Skewness: {age_skewness:.2f}', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)
plt.text(0.7, 0.85, f'Kurtosis: {age_kurtosis:.2f}', ha='center', va='center', transform=plt.gca().transAxes, fontsize=12)
plt.show()

# %%
s
